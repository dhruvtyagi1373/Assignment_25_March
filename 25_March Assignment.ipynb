# %% [markdown]
# ## Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
df = pd.read_excel('flight_price.xlsx')

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# It has 10683 rows and 11 columns

# %% [markdown]
# ## Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
import seaborn as sns
sns.histplot(df['Price'],bins=30,kde=True,color='red')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ## Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %% [markdown]
# Range : 1759-79512
#
# Minimumn = 1759,Maximum = 79512

# %% [markdown]
# ## Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,15))
sns.boxplot(x=df['Airline'],y=df['Price'],)
plt.xticks(rotation=90)
plt.xlabel('Airlines')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ### Observation
# Jet Airways has the highest flight ticket price followed by Multiple Carriers and Jet Airways

# %% [markdown]
# ## Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %% [raw]
# based on the above boxplot there are outliers in the dataset.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,15))
sns.boxplot(x=df['Airline'],y=df['Price'],)
plt.xticks(rotation=90)
plt.xlabel('Airlines')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Outliers increase the variability in your data, which decreases statistical power. Consequently, excluding outliers can cause your results to become statistically significant

# %% [markdown]
# ## Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
df['Day'] = df['Date_of_Journey'].str.split('/').str[0]
df['Month'] = df['Date_of_Journey'].str.split('/').str[1]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1
#
#   Month  Year
# 0    03  2019
# 1    05  2019

# %% [markdown]
# ## I would analyze Date_Of_Journey Feature to find peak season.

# %%
df['Month'].value_counts()
# Out:
# 05    3466
# 06    3414
# 03    2724
# 04    1079
# Name: Month, dtype: int64

# %% [markdown]
# ## Observation
# Since, Most no. of flight tickets are in 5th and 6th Month of the year i.e.May and June.So, the peak season is in the month May and June.

# %% [markdown]
# ### I would use piechart to present this to my boss.

# %%
df['Month'].value_counts().plot.pie(y=df['Month'],autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Month'>

# %% [markdown]
# ## Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1
#
#   Month  Year
# 0    03  2019
# 1    05  2019

# %%
df['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
sns.histplot(x=df['Total_Stops'],color='r')
# Out:
# <AxesSubplot: xlabel='Total_Stops', ylabel='Count'>

# %%
sns.barplot(x=df['Total_Stops'],y=df['Price'],color='g')
# Out:
# <AxesSubplot: xlabel='Total_Stops', ylabel='Price'>

# %% [markdown]
# ## Observations
#
# 1. Flights having 4 stops are having much more price than compared to 3 or lesser stops.
# 2. Flights having 1 stop have maximum number of tickets booked.

# %%
df['Duration'].value_counts()
# Out:
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 31h 30m      1
# 30h 25m      1
# 42h 5m       1
# 4h 10m       1
# 47h 40m      1
# Name: Duration, Length: 368, dtype: int64

# %%
df['Hours'] = df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df['Hours'].value_counts().plot.pie(y=df['Hours'],figsize=(10,16),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Hours'>

# %% [markdown]
# ## Observations
# Most Number of tickets are booked for flights having Duration less than 3 hours.

# %% [markdown]
# ## Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# Same answer as Above

# %% [markdown]
# ## Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# ## It has 10841 rows and 13 columns

# %% [markdown]
# ## Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
df1.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df1['Category'],y=df1['Rating'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ### Yes there are missing values in the dataset.

# %% [markdown]
# ### The presence of missing values reduces the data available to be analyzed, compromising the statistical power of the study, and eventually the reliability of its results.

# %% [markdown]
# ## Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
df1.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df1['Size'],y=df1['Rating'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df1.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
dfa = df1.groupby(['Price','Type']).mean().reset_index()
# Out:
# /tmp/ipykernel_3244/1165867942.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfa = df1.groupby(['Price','Type']).mean().reset_index()

# %%
dfa[['Price','Type']]
# Out:
#        Price  Type
# 0      $0.99  Paid
# 1      $1.00  Paid
# 2      $1.04  Paid
# 3      $1.20  Paid
# 4      $1.26  Paid
# ..       ...   ...
# 88    $89.99  Paid
# 89     $9.00  Paid
# 90     $9.99  Paid
# 91         0  Free
# 92  Everyone     0
#
# [93 rows x 2 columns]

# %%
df3 = dfa[['Price','Type']].sort_values('Price',ascending=False)

# %%
df3.drop(index=92)
# Out:
#      Price  Type
# 91       0  Free
# 90   $9.99  Paid
# 89   $9.00  Paid
# 88  $89.99  Paid
# 87   $8.99  Paid
# ..     ...   ...
# 4    $1.26  Paid
# 3    $1.20  Paid
# 2    $1.04  Paid
# 1    $1.00  Paid
# 0    $0.99  Paid
#
# [92 rows x 2 columns]

# %%
sns.barplot(y=df1.groupby(['Price','Type']).mean()[:10],x=df1['Type'])
# Out:
# /tmp/ipykernel_3244/367661728.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.barplot(y=df1.groupby(['Price','Type']).mean()[:10],x=df1['Type'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.barplot(y=df1.groupby(['Price','Type']).mean()[:10],x=df1['Type'])
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:2754, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2751 if estimator is len:
#    2752     estimator = "size"
# ...

# %%
df1['Price'].unique()

# %%
sns.barplot(x=df1['Type'],y=df1['Price'])

# %% [markdown]
# ## Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
obj_to_replace = [',','+']
for item in obj_to_replace:
    df1['Installs']=df1['Installs'].str.replace(item,'')
# Out:
# /tmp/ipykernel_3244/4001700080.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1['Installs']=df1['Installs'].str.replace(item,'')

# %%
df1[df1['Installs']=='']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df1=df1.drop(index=10472)

# %%
df1['Installs']=df1['Installs'].astype(int)

# %%
df_cat_installs = df1.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions
df2 = df_cat_installs.head(10)

# %%
df2
# Out:
#              Category   Installs
# 0                GAME  35.086024
# 1       COMMUNICATION  32.647276
# 2        PRODUCTIVITY  14.176091
# 3              SOCIAL  14.069868
# 4               TOOLS  11.452772
# 5              FAMILY  10.258264
# 6         PHOTOGRAPHY  10.088248
# 7  NEWS_AND_MAGAZINES   7.496318
# 8    TRAVEL_AND_LOCAL   6.868887
# 9       VIDEO_PLAYERS   6.222003

# %% [markdown]
# ## Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %% [markdown]
# #### I would analyze the Google Play Store dataset by looking for app category and Type Features having highest downloads and having Type=Free.

# %%
df1.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M     10000  Free     0       Everyone
# 1     967  14M    500000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df2
# Out:
#              Category   Installs
# 0                GAME  35.086024
# 1       COMMUNICATION  32.647276
# 2        PRODUCTIVITY  14.176091
# 3              SOCIAL  14.069868
# 4               TOOLS  11.452772
# 5              FAMILY  10.258264
# 6         PHOTOGRAPHY  10.088248
# 7  NEWS_AND_MAGAZINES   7.496318
# 8    TRAVEL_AND_LOCAL   6.868887
# 9       VIDEO_PLAYERS   6.222003

# %%
df1['Type'].value_counts().plot.pie(y=df1['Type'],autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Type'>

# %% [markdown]
# ## Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
df1.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M     10000  Free     0       Everyone
# 1     967  14M    500000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# ## I would use Category,Rating,Type features to make recommendations to the company.

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df1['Category'],y=df1['Rating'])
plt.xticks(rotation=90)
plt.show()

# %%
df1['Type'].value_counts().plot.pie(y=df1['Type'],autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Type'>

# %% [markdown]
# ## Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# ## same as previous answer

# %% [raw]
# I would recommend that there is no best time to launch a new app based on the analysis of dataset
